# %% [markdown]
# <a href="https://colab.research.google.com/github/Anna-Pramod/April-LeetCoding-Challenge-2021/blob/main/Chatbot_Arena_Elo_Ratings_Calculation_(May_1%2C_2023).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction
#
# In this notebook, we will employ the Elo rating system to evaluate the performance of large language models (LLMs).
# The analysis is based on the pairwise battle results we collected from https://arena.lmsys.org between April 24 and May 1, 2023.
# This crowdsourcing way of data collection represents some use cases of LLMs in the wild.
# Below, we present the calculation procedure along with some basic analyses.

# %%
from collections import defaultdict
import json, math, gdown
import numpy as np
import pandas as pd
import plotly.express as px
from tqdm import tqdm
pd.options.display.float_format = '{:.2f}'.format

# %% [markdown]
# # Obtaining and Cleaning the Tournament Data
# We are hosting the initial tournament results as a JSON file on Google Drive. We use the `gdown` function to download the data. The data only contains voting results without conversation histories because releasing the conversation history will raise concerns such as privacy and toxicity.

# %%
url = "https://drive.google.com/file/d/1DljLStkGSSwXecevGzsqD6cGxm3LERxG/view?usp=sharing"
gdown.download(url, quiet=False, fuzzy=True)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1DljLStkGSSwXecevGzsqD6cGxm3LERxG
# To: /content/clean_battle_20230501.json
# 100%|██████████| 1.67M/1.67M [00:00<00:00, 27.8MB/s]
# 'clean_battle_20230501.json'

# %%
raw_data = pd.read_json("clean_battle_20230501.json").sort_values(ascending=True, by=["tstamp"])
raw_data
# Out:
#          model_a                  model_b      win  anony        tstamp  \
# 761   alpaca-13b             dolly-v2-12b  model_b  False 1682295238.71
# 762    koala-13b             dolly-v2-12b  model_b  False 1682295376.63
# 763    koala-13b             dolly-v2-12b  model_b  False 1682295408.08
# 764    koala-13b             dolly-v2-12b  model_b  False 1682295434.13
# 765   vicuna-13b                koala-13b  model_a  False 1682295451.25
# ...          ...                      ...      ...    ...           ...
# 9775  vicuna-13b                koala-13b  model_a  False 1682982812.03
# 9598  chatglm-6b  stablelm-tuned-alpha-7b  model_a   True 1682982923.13
# 9776  vicuna-13b                koala-13b  model_a   True 1682982943.31
# 9777  alpaca-13b             dolly-v2-12b  model_b   True 1682983185.82
# 9840  alpaca-13b             dolly-v2-12b  model_a   True 1682983896.20
#
#      language
# 761   English
# 762   English
# 763   English
# 764   English
# 765   English
# ...       ...
# 9775  English
# 9598  English
# 9776  English
# 9777  English
# 9840  English
#
# [9841 rows x 6 columns]

# %% [markdown]
# ## Removing the Non Anonymous Pairings
# The lmsys data also includes the side-by-side chat web interface where users were able to see (and select) which models were paired. In this case, the battles were **not anonymous**. We have included this data for others to study but it was not part of the tournament so we drop these records from the remaining analysis.

# %%
raw_data['anony'].value_counts()
# Out:
# False    5152
# True     4689
# Name: anony, dtype: int64

# %%
battles = raw_data[raw_data['anony']].reset_index(drop=True)
battles
# Out:
#                model_a                  model_b            win  anony  \
# 0           chatglm-6b                koala-13b        model_b   True
# 1     oasst-pythia-12b               alpaca-13b            tie   True
# 2            koala-13b         oasst-pythia-12b        model_b   True
# 3           vicuna-13b         oasst-pythia-12b        model_b   True
# 4           vicuna-13b                koala-13b        model_a   True
# ...                ...                      ...            ...    ...
# 4684        chatglm-6b               alpaca-13b  tie (bothbad)   True
# 4685        chatglm-6b  stablelm-tuned-alpha-7b        model_a   True
# 4686        vicuna-13b                koala-13b        model_a   True
# 4687        alpaca-13b             dolly-v2-12b        model_b   True
# 4688        alpaca-13b             dolly-v2-12b        model_a   True
#
#             tstamp language
# 0    1682351591.13  English
# 1    1682351654.67  English
# 2    1682351708.94  English
# 3    1682351785.19  English
# 4    1682351891.66  English
# ...            ...      ...
# 4684 1682982673.43  English
# 4685 1682982923.13  English
# 4686 1682982943.31  English
# 4687 1682983185.82  English
# 4688 1682983896.20  English
#
# [4689 rows x 6 columns]

# %% [markdown]
# # Exploratory Analysis
#
# Before computing the Elo ratings, we first conduct some basic exploratory analysis to highlight a few key properties and caveates with this data.

# %% [markdown]
# ## Signfiicant Number of Ties
#
# We allowed the user to declare a tie between the pairs of models.  To collect additional data, later in the tournament we also allowed the user to declare a tie in which both models were bad.  There were a significant number of tied outcomes.

# %%
fig = px.bar(battles["win"].value_counts(),
             title="Counts of Battle Outcomes", text_auto=True, height=400)
fig.update_layout(xaxis_title="Battle Outcome", yaxis_title="Count",
                  showlegend=False)
# save for blog
fig.write_html("outcome_counts.html", full_html=False, include_plotlyjs="cdn")
fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="fb0d9f09-50b6-4f97-82db-d2325590bb85" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fb0d9f09-50b6-4f97-82db-d2325590bb85")) {                    Plotly.newPlot(                        "fb0d9f09-50b6-4f97-82db-d2325590bb85",                        [{"alignmentgroup":"True","hovertemplate":"variable=win<br>index=%{x}<br>value=%{y}<extra></extra>","legendgroup":"win","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"win","offsetgroup":"win","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["model_a","model_b","tie (bothbad)","tie"],"xaxis":"x","y":[1758,1590,819,522],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"tic ...

# %%
battles_no_ties = battles[~battles["win"].str.contains("tie")]

# %% [markdown]
# ## Non-uniform Model Frequency
#
# When we initially launched the tournament, we had prior information on the likely ranking based on our benchmarks and chose to pair models according to this ranking. We gave preference to what we believed would be strong pairings based on this ranking. However, we later switched to uniform sampling to get better overall coverage of the rankings.
# Towards the end of the tournament, we also introduced a new model `fastchat-t5-3b`.
# All of these result in non-uniform model frequency.

# %%
fig = px.bar(pd.concat([battles["model_a"], battles["model_b"]]).value_counts(),
             title="Battle Count for Each Model", text_auto=True)
fig.update_layout(xaxis_title="model", yaxis_title="Battle Count",
                  showlegend=False)
# save the plot for the blog:
fig.write_html("model_counts.html", full_html=False, include_plotlyjs="cdn")
fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="2fcd5f5c-8780-47a4-9481-45ee9fd5cb01" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2fcd5f5c-8780-47a4-9481-45ee9fd5cb01")) {                    Plotly.newPlot(                        "2fcd5f5c-8780-47a4-9481-45ee9fd5cb01",                        [{"alignmentgroup":"True","hovertemplate":"variable=0<br>index=%{x}<br>value=%{y}<extra></extra>","legendgroup":"0","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"0","offsetgroup":"0","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["vicuna-13b","koala-13b","oasst-pythia-12b","dolly-v2-12b","alpaca-13b","llama-13b","stablelm-tuned-alpha-7b","chatglm-6b","fastchat-t5-3b"],"xaxis":"x","y":[2024,1489,1137,951,929,926,905,851,166],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10 ...

# %% [markdown]
# We examing the number of pairings for each combination of models.

# %%
def visualize_battle_count(battles, title):
    ptbl = pd.pivot_table(battles, index="model_a", columns="model_b", aggfunc="size",
                          fill_value=0)
    battle_counts = ptbl + ptbl.T
    ordering = battle_counts.sum().sort_values(ascending=False).index
    fig = px.imshow(battle_counts.loc[ordering, ordering],
                    title=title, text_auto=True, width=600)
    fig.update_layout(xaxis_title="Model B",
                      yaxis_title="Model A",
                      xaxis_side="top",
                      title_y=0.07, title_x=0.5)
    fig.update_traces(hovertemplate=
                      "Model A: %{y}<br>Model B: %{x}<br>Count: %{z}<extra></extra>")
    return fig

fig = visualize_battle_count(battles, title="Battle Count of Each Combination of Models")
# save for blog
fig.write_html("battle_counts.html", full_html=True, include_plotlyjs="cdn")
fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="b99ca3f5-3e99-475f-9242-ece4d80fcdc8" class="plotly-graph-div" style="height:525px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b99ca3f5-3e99-475f-9242-ece4d80fcdc8")) {                    Plotly.newPlot(                        "b99ca3f5-3e99-475f-9242-ece4d80fcdc8",                        [{"coloraxis":"coloraxis","name":"0","texttemplate":"%{z}","x":["vicuna-13b","koala-13b","oasst-pythia-12b","dolly-v2-12b","alpaca-13b","llama-13b","stablelm-tuned-alpha-7b","chatglm-6b","fastchat-t5-3b"],"y":["vicuna-13b","koala-13b","oasst-pythia-12b","dolly-v2-12b","alpaca-13b","llama-13b","stablelm-tuned-alpha-7b","chatglm-6b","fastchat-t5-3b"],"z":[[0,621,345,219,210,213,189,204,23],[621,0,192,129,153,149,127,104,14],[345,192,0,120,111,108,139,95,27],[219,129,120,0,118,121,103,116,25],[210,153,111,118,0,102,105,114,16],[213,149,108,121,102,0,118,95,20],[189,127,139,103,105,118,0,103,21],[204,104,95,116,114,95,103,0,20],[23,14,27,25,16,20,21,20,0]],"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"Model A: %{y}<br>Model B: %{x}<br>Count: %{z}<extra></extra>"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewi ...

# %% [markdown]
# ### Battles Excluding Ties

# %%
visualize_battle_count(battles_no_ties, "Battle Count for Each Combination of Models (without Ties)")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="2e060fef-a59e-4c06-94cc-8066fe3925ab" class="plotly-graph-div" style="height:525px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2e060fef-a59e-4c06-94cc-8066fe3925ab")) {                    Plotly.newPlot(                        "2e060fef-a59e-4c06-94cc-8066fe3925ab",                        [{"coloraxis":"coloraxis","name":"0","texttemplate":"%{z}","x":["vicuna-13b","koala-13b","oasst-pythia-12b","llama-13b","dolly-v2-12b","alpaca-13b","stablelm-tuned-alpha-7b","chatglm-6b","fastchat-t5-3b"],"y":["vicuna-13b","koala-13b","oasst-pythia-12b","llama-13b","dolly-v2-12b","alpaca-13b","stablelm-tuned-alpha-7b","chatglm-6b","fastchat-t5-3b"],"z":[[0,422,261,185,184,166,144,158,17],[422,0,135,107,99,103,92,74,12],[261,135,0,70,71,74,91,64,18],[185,107,70,0,77,75,91,59,15],[184,99,71,77,0,79,65,79,14],[166,103,74,75,79,0,70,84,9],[144,92,91,91,65,70,0,58,15],[158,74,64,59,79,84,58,0,11],[17,12,18,15,14,9,15,11,0]],"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"Model A: %{y}<br>Model B: %{x}<br>Count: %{z}<extra></extra>"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpola ...

# %% [markdown]
# ### Counting Ties

# %%
visualize_battle_count(battles[battles['win'].str.contains("tie")], "Tie Count for Each Combination of Models")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="040ff2cf-1861-4660-ab13-a8ea7b8443f6" class="plotly-graph-div" style="height:525px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("040ff2cf-1861-4660-ab13-a8ea7b8443f6")) {                    Plotly.newPlot(                        "040ff2cf-1861-4660-ab13-a8ea7b8443f6",                        [{"coloraxis":"coloraxis","name":"0","texttemplate":"%{z}","x":["vicuna-13b","koala-13b","oasst-pythia-12b","dolly-v2-12b","stablelm-tuned-alpha-7b","alpaca-13b","chatglm-6b","llama-13b","fastchat-t5-3b"],"y":["vicuna-13b","koala-13b","oasst-pythia-12b","dolly-v2-12b","stablelm-tuned-alpha-7b","alpaca-13b","chatglm-6b","llama-13b","fastchat-t5-3b"],"z":[[0,199,84,35,45,44,46,28,6],[199,0,57,30,35,50,30,42,2],[84,57,0,49,48,37,31,38,9],[35,30,49,0,38,39,37,44,11],[45,35,48,38,0,35,45,27,6],[44,50,37,39,35,0,30,27,7],[46,30,31,37,45,30,0,36,9],[28,42,38,44,27,27,36,0,5],[6,2,9,11,6,7,9,5,0]],"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"Model A: %{y}<br>Model B: %{x}<br>Count: %{z}<extra></extra>"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl" ...

# %% [markdown]
# ## Inferred Language
#
# We also inferred the language for each of the the conversations using `polyglot` package. This is just an estimate but will help guide future analysis.  The vast majority of conversations were in English.

# %%
topk = 15
fig = px.bar(battles["language"].value_counts().head(topk),
             title=f"Battle Counts for the Top {topk} Languages",
             text_auto=True, height=400)
fig.update_layout(xaxis_title="Language", yaxis_title="Count", showlegend=False)
fig.write_html("language_counts.html", full_html=False, include_plotlyjs="cdn")
fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="0f440ed4-4785-4899-954b-a8464ec0887b" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0f440ed4-4785-4899-954b-a8464ec0887b")) {                    Plotly.newPlot(                        "0f440ed4-4785-4899-954b-a8464ec0887b",                        [{"alignmentgroup":"True","hovertemplate":"variable=language<br>index=%{x}<br>value=%{y}<extra></extra>","legendgroup":"language","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"language","offsetgroup":"language","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["English","Chinese","Spanish","unknown","Russian","Portuguese","Japanese","French","German","Italian","Polish","Czech","Scots","Latin","Arabic"],"xaxis":"x","y":[3736,327,103,93,66,64,50,43,40,32,17,9,9,9,9],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pa ...

# %% [markdown]
# ## Pairwise Win Fractions
#
# Finally, we can also compute the pairwise win fractions. However, because each model can play as Model A and as Model B and win in both situations we need to compute the wins in both configurations divided by the number of pairings of each model.

# %%
def compute_pairwise_win_fraction(battles):
    # Times each model wins as Model A
    a_win_ptbl = pd.pivot_table(
        battles[battles['win'] == "model_a"],
        index="model_a", columns="model_b", aggfunc="size", fill_value=0)

    # Table counting times each model wins as Model B
    b_win_ptbl = pd.pivot_table(
        battles[battles['win'] == "model_b"],
        index="model_a", columns="model_b", aggfunc="size", fill_value=0)

    # Table counting number of A-B pairs
    num_battles_ptbl = pd.pivot_table(battles,
        index="model_a", columns="model_b", aggfunc="size", fill_value=0)

    # Computing the proportion of wins for each model as A and as B
    # against all other models
    row_beats_col_freq = (
        (a_win_ptbl + b_win_ptbl.T) /
        (num_battles_ptbl + num_battles_ptbl.T)
    )

    # Arrange ordering according to proprition of wins
    prop_wins = row_beats_col_freq.mean(axis=1).sort_values(ascending=False)
    model_names = list(prop_wins.keys())
    row_beats_col = row_beats_col_freq.loc[model_names, model_names]
    return row_beats_col

def visualize_pairwise_win_fraction(battles, title):
    row_beats_col = compute_pairwise_win_fraction(battles)
    fig = px.imshow(row_beats_col, color_continuous_scale='RdBu',
                    text_auto=".2f", title=title)
    fig.update_layout(xaxis_title="Model B",
                  yaxis_title="Model A",
                  xaxis_side="top",
                  title_y=0.07, title_x=0.5)
    fig.update_traces(hovertemplate=
                  "Model A: %{y}<br>Model B: %{x}<br>Fraction of A Wins: %{z}<extra></extra>")

    return fig

# %%
fig = visualize_pairwise_win_fraction(battles_no_ties,
      title = "Fraction of Model A Wins for All Non-tied A vs. B Battles")
fig.write_html("row_beats_column_probs.html", full_html=False, include_plotlyjs="cdn")
fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="55e9f109-a1d0-4028-b730-f018e5fc288c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("55e9f109-a1d0-4028-b730-f018e5fc288c")) {                    Plotly.newPlot(                        "55e9f109-a1d0-4028-b730-f018e5fc288c",                        [{"coloraxis":"coloraxis","name":"0","texttemplate":"%{z:.2f}","x":["vicuna-13b","koala-13b","alpaca-13b","oasst-pythia-12b","chatglm-6b","fastchat-t5-3b","dolly-v2-12b","stablelm-tuned-alpha-7b","llama-13b"],"y":["vicuna-13b","koala-13b","alpaca-13b","oasst-pythia-12b","chatglm-6b","fastchat-t5-3b","dolly-v2-12b","stablelm-tuned-alpha-7b","llama-13b"],"z":[[null,0.6800947867298578,0.7710843373493976,0.7739463601532567,0.8227848101265823,0.9411764705882353,0.8858695652173914,0.7847222222222222,0.8486486486486486],[0.31990521327014215,null,0.6504854368932039,0.6592592592592592,0.7432432432432432,0.75,0.7676767676767676,0.8369565217391305,0.8130841121495327],[0.2289156626506024,0.34951456310679613,null,0.44594594594594594,0.5119047619047619,0.7777777777777778,0.7468354430379747,0.7142857142857143,0.7466666666666667],[0.2260536398467433,0.34074074074074073,0.5540540540540541,null,0.578125,0.5,0.6056338028169014,0.6483516483516484,0.7571428571428571],[0.17721518987341772,0.25675675675675674,0.4880952380952381,0.421875,null,0.36363636363636365,0.569620253164557,0.5517241379310345,0.711864406779661],[0.058823529411764705,0.25,0.2222222222222222,0.5,0.6363636363636364,null,0.5,0.6,0.4666666666666667],[0.11413043478260869,0.23232323232323232,0.25316455696202533,0.39436619718309857,0.43037974683544306,0.5,null,0.5076923076923077,0.6233766233766234],[0.2152777777777778,0.16304347826086957,0.2857142857142857,0.3516483516483517,0.4482758620689655,0.4,0.49230769230769234,null,0.6153846153846154],[0.15135135135135136,0.18691588785046728,0.25333333333333335,0.24285714285714285,0.288135593220339,0.5333333333333333,0.37662337662337664,0.38461538461538464,null]],"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"Model A: %{y}<br>Model B: %{x}<br>Fraction of A Wins: %{z}<extra></extra>"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"t ...

# %% [markdown]
# ## Preliminary Ranking
#
# Using just the average win rate against all other models we can already compute an estimated leaderboard.
# However, this method may not be as scalable as the Elo rating system that we will use later because this method requires data from all model combinations.

# %%
row_beats_col_freq = compute_pairwise_win_fraction(battles_no_ties)
fig = px.bar(row_beats_col_freq.mean(axis=1).sort_values(ascending=False),
             title="Average Win Rate Against All Other Models (Assuming Uniform Sampling and No Ties)",
             text_auto=".2f")
fig.update_layout(yaxis_title="Average Win Rate", xaxis_title="Model",
                  showlegend=False)
fig.write_html("average_win_rate.html", full_html=False, include_plotlyjs="cdn")
fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="147a54b6-9fb8-42b3-a6a4-c209369b16cb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("147a54b6-9fb8-42b3-a6a4-c209369b16cb")) {                    Plotly.newPlot(                        "147a54b6-9fb8-42b3-a6a4-c209369b16cb",                        [{"alignmentgroup":"True","hovertemplate":"variable=0<br>model_a=%{x}<br>value=%{y}<extra></extra>","legendgroup":"0","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"0","offsetgroup":"0","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y:.2f}","x":["vicuna-13b","koala-13b","alpaca-13b","oasst-pythia-12b","chatglm-6b","fastchat-t5-3b","dolly-v2-12b","stablelm-tuned-alpha-7b","llama-13b"],"xaxis":"x","y":[0.8135409001294489,0.6925763192789098,0.56523081692203,0.5262627178691182,0.4425984182796286,0.40425950683303624,0.38192913739441736,0.37145650789531975,0.30214567539809106],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x": ...

# %% [markdown]
# #Elo Ratings
#
# The [Elo rating system ](https://en.wikipedia.org/wiki/Elo_rating_system)is a method for calculating the relative skill levels of players, which has been widely adopted in chess, sports, and MOBA games. The difference in the ratings between two players serves as a predictor of the outcome of a match. The Elo rating system works well for our case because we have multiple models and we run pairwise battles between them.
# Next, we compute the Elo ratings of these models.

# %% [markdown]
# ### Compute Ratings
#
# We first use the online linear update algorithm to compute Elo ratings.
# This is the algorithm we used for our default leaderboard.

# %%
def compute_elo(battles, K=32, SCALE=400, BASE=10, INIT_RATING=1000):
    rating = defaultdict(lambda: INIT_RATING)

    for rd, model_a, model_b, win in battles[['model_a', 'model_b', 'win']].itertuples():
        ra = rating[model_a]
        rb = rating[model_b]
        ea = 1 / (1 + BASE ** ((rb - ra) / SCALE))
        eb = 1 / (1 + BASE ** ((ra - rb) / SCALE))
        if win == "model_a":
            sa = 1
        elif win == "model_b":
            sa = 0
        elif win == "tie" or win == "tie (bothbad)":
            sa = 0.5
        else:
            raise Exception(f"unexpected vote {win}")
        rating[model_a] += K * (sa - ea)
        rating[model_b] += K * (1 - sa - eb)

    return rating

# %%
elo_ratings = compute_elo(battles)
df = pd.DataFrame([
    [n, elo_ratings[n]] for n in elo_ratings.keys()
], columns=["Model", "Elo rating"]).sort_values("Elo rating", ascending=False).reset_index(drop=True)
df["Elo rating"] = df["Elo rating"].astype(int)
df
# Out:
#                      Model  Elo rating
# 0               vicuna-13b        1169
# 1                koala-13b        1082
# 2         oasst-pythia-12b        1065
# 3               alpaca-13b        1008
# 4               chatglm-6b         985
# 5           fastchat-t5-3b         951
# 6             dolly-v2-12b         944
# 7                llama-13b         932
# 8  stablelm-tuned-alpha-7b         858

# %%
def predict_win_rate(elo_ratings, K=32, SCALE=400, BASE=10, INIT_RATING=1000):
    names = sorted(list(elo_ratings.keys()))
    wins = defaultdict(lambda: defaultdict(lambda: 0))
    for a in names:
        for b in names:
            ea = 1 / (1 + BASE ** ((elo_ratings[b] - elo_ratings[a]) / SCALE))
            wins[a][b] = ea
            wins[b][a] = 1 - ea

    data = {
        a: [wins[a][b] if a != b else np.NAN for b in names]
        for a in names
    }

    df = pd.DataFrame(data, index=names)
    df.index.name = "model_a"
    df.columns.name = "model_b"
    return df.T

# %%
win_rate = predict_win_rate(compute_elo(battles))
ordered_models = win_rate.mean(axis=1).sort_values(ascending=False).index
fig = px.imshow(win_rate.loc[ordered_models, ordered_models],
                color_continuous_scale='RdBu', text_auto=".2f",
                title="Predicted Win Rate Using Elo Ratings for Model A in an A vs. B Battle")
fig.update_layout(xaxis_title="Model B",
                  yaxis_title="Model A",
                  xaxis_side="top",
                  title_y=0.07, title_x=0.5)
fig.update_traces(hovertemplate=
                  "Model A: %{y}<br>Model B: %{x}<br>Win Rate: %{z}<extra></extra>")
fig.write_html("elo_predicted_win_rate.html", full_html=False, include_plotlyjs="cdn")
fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="80802f8f-2da1-42dc-8819-c5158f5d6330" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("80802f8f-2da1-42dc-8819-c5158f5d6330")) {                    Plotly.newPlot(                        "80802f8f-2da1-42dc-8819-c5158f5d6330",                        [{"coloraxis":"coloraxis","name":"0","texttemplate":"%{z:.2f}","x":["vicuna-13b","koala-13b","oasst-pythia-12b","alpaca-13b","chatglm-6b","fastchat-t5-3b","dolly-v2-12b","llama-13b","stablelm-tuned-alpha-7b"],"y":["vicuna-13b","koala-13b","oasst-pythia-12b","alpaca-13b","chatglm-6b","fastchat-t5-3b","dolly-v2-12b","llama-13b","stablelm-tuned-alpha-7b"],"z":[[null,0.6219313168433799,0.6457862891183916,0.7160300141211027,0.7421056446238347,0.7776835166557939,0.7846510278491312,0.7968263609576549,0.8566118819385057],[0.3780686831566201,null,0.5256809841600314,0.6051809040461371,0.6362645926281563,0.6801505817198555,0.6889522326393307,0.7045005274483107,0.7840923585178168],[0.35421371088160836,0.47431901583996855,null,0.5803682665797517,0.6121534921578803,0.6573820751370218,0.666503059064909,0.6826566292223611,0.7661793078398587],[0.2839699858788973,0.3948190959538629,0.4196317334202483,null,0.5329740839854016,0.581117895325467,0.5910060024269223,0.608669337773692,0.7031986431413089],[0.25789435537616534,0.36373540737184373,0.3878465078421197,0.46702591601459836,null,0.5486644800663663,0.5587369592064964,0.5767959772484232,0.674912414140852],[0.22231648334420606,0.31984941828014446,0.34261792486297815,0.4188821046745331,0.45133551993363374,null,0.5101889759616097,0.5285584153688597,0.6306979491884985],[0.2153489721508688,0.3110477673606693,0.33349694093509097,0.40899399757307775,0.4412630407935037,0.4898110240383903,null,0.5183908449536381,0.6211543275645977],[0.2031736390423451,0.29549947255168935,0.31734337077763886,0.391330662226308,0.4232040227515768,0.4714415846311403,0.481609155046362,null,0.6036876006133516],[0.14338811806149432,0.21590764148218317,0.23382069216014129,0.2968013568586911,0.325087585859148,0.3693020508115014,0.37884567243540235,0.39631239938664836,null]],"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"Model A: %{y}<br>Model B: %{x}<br>Win Rate: %{z}<extra></extra>"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.666666666 ...

# %% [markdown]
# ### Compute Bootstrap Confidence Interavals for Elo Scores
#
# The previous linear update method may be sensitive to battle orders. Here we use bootstrap to estimate the confidence intervals

# %%
def get_bootstrap_result(battles, func_compute_elo, num_round):
    rows = []
    for i in tqdm(range(num_round), desc="bootstrap"):
        rows.append(func_compute_elo(battles.sample(frac=1.0, replace=True)))
    df = pd.DataFrame(rows)
    return df[df.median().sort_values(ascending=False).index]

# %%
BOOTSTRAP_ROUNDS = 1000

bootstrap_elo_lu = get_bootstrap_result(battles, compute_elo, BOOTSTRAP_ROUNDS)
bootstrap_lu_median = bootstrap_elo_lu.median().reset_index().set_axis(["model", "rating"], axis=1)
bootstrap_lu_median
# Out:
# bootstrap: 100%|██████████| 1000/1000 [00:25<00:00, 38.52it/s]
#                      model  rating
# 0               vicuna-13b 1172.29
# 1                koala-13b 1090.09
# 2               alpaca-13b 1018.52
# 3         oasst-pythia-12b 1013.70
# 4               chatglm-6b  976.55
# 5           fastchat-t5-3b  951.51
# 6  stablelm-tuned-alpha-7b  949.44
# 7             dolly-v2-12b  935.08
# 8                llama-13b  891.67

# %%
def visualize_bootstrap_scores(df, title):
    bars = pd.DataFrame(dict(
        lower = df.quantile(.025),
        rating = df.quantile(.5),
        upper = df.quantile(.975))).reset_index(names="model").sort_values("rating", ascending=False)
    bars['error_y'] = bars['upper'] - bars["rating"]
    bars['error_y_minus'] = bars['rating'] - bars["lower"]
    bars['rating_rounded'] = np.round(bars['rating'], 2)
    fig = px.scatter(bars, x="model", y="rating", error_y="error_y",
                      error_y_minus="error_y_minus", text="rating_rounded",
                      title=title)
    fig.update_layout(xaxis_title="Model", yaxis_title="Rating")
    return fig

fig = visualize_bootstrap_scores(bootstrap_elo_lu, "Bootstrap of Elo Estimates")
fig.write_html("bootstrap_elo_estimates.html", full_html=False, include_plotlyjs="cdn")
fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="c93774b7-f61b-4890-9af8-9df61bf9edd5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c93774b7-f61b-4890-9af8-9df61bf9edd5")) {                    Plotly.newPlot(                        "c93774b7-f61b-4890-9af8-9df61bf9edd5",                        [{"error_y":{"array":[84.53458324007852,80.5958609215852,82.83056617492764,76.7372302030717,86.2796140515236,86.36745686362383,73.91006105388999,82.06220015378369,85.10799659708027],"arrayminus":[84.39382269417092,81.57745430981345,86.98258944674205,83.3158831194977,85.30388746508413,79.18703743349022,84.5925201888283,81.7373417544461,79.84604202398896]},"hovertemplate":"model=%{x}<br>rating=%{y}<br>rating_rounded=%{text}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers+text","name":"","orientation":"v","showlegend":false,"text":[1172.29,1090.09,1018.52,1013.7,976.55,951.51,949.44,935.08,891.67],"x":["vicuna-13b","koala-13b","alpaca-13b","oasst-pythia-12b","chatglm-6b","fastchat-t5-3b","stablelm-tuned-alpha-7b","dolly-v2-12b","llama-13b"],"xaxis":"x","y":[1172.2908203172751,1090.0874686178267,1018.521212227501,1013.6971200076312,976.5492722344427,951.5087429044477,949.4405645957945,935.0763810264125,891.6677616639704],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}], ...

# %% [markdown]
# ### Compute Bootstrap Confidence Intervals Assuming Uniform Sampling

# %%
def sample_battle_even(battles, n_per_battle):
    groups = battles.groupby(["model_a", "model_b"], as_index=False)
    resampled = (groups
                 .apply(lambda grp: grp.sample(n_per_battle, replace=True))
                 .reset_index(drop=True))
    return resampled

# %%
num_samples = 50
battles_even = sample_battle_even(battles, num_samples)
pd.pivot_table(battles_even, index="model_a", columns="model_b", aggfunc="size", fill_value=0)
# Out:
# model_b                  alpaca-13b  chatglm-6b  dolly-v2-12b  fastchat-t5-3b  \
# model_a
# alpaca-13b                        0          50            50              50
# chatglm-6b                       50           0            50              50
# dolly-v2-12b                     50          50             0              50
# fastchat-t5-3b                   50          50            50               0
# koala-13b                        50          50            50              50
# llama-13b                        50          50            50              50
# oasst-pythia-12b                 50          50            50              50
# stablelm-tuned-alpha-7b          50          50            50              50
# vicuna-13b                       50          50            50              50
#
# model_b                  koala-13b  llama-13b  oasst-pythia-12b  \
# model_a
# alpaca-13b                      50         50                50
# chatglm-6b                      50         50                50
# dolly-v2-12b                    50         50                50
# fastchat-t5-3b                  50         50                50
# koala-13b                        0         50                50
# llama-13b                       50          0                50
# oasst-pythia-12b                50         50                 0
# stablelm-tuned-alpha-7b         50         50                50
# vicuna-13b                      50         50                50
#
# model_b                  stablelm-tuned-alpha-7b  vicuna-13b
# model_a
# alpaca-13b                                    50          50
# chatglm-6b                                    50          50
# dolly-v2-12b                                  50          50
# fastchat-t5-3b                                50          50
# koala-13b                                     50          50
# llama-13b                                     50          50
# oasst-pythia-12b                              50          50
# stablelm-tuned-alpha-7b                        0          50
# vicuna-13b                                    50           0

# %%
# Sampling Battles Evenly
def get_bootstrap_even_sample(battles, n_per_battle, func_compute_elo, num_round=BOOTSTRAP_ROUNDS):
    rows = []
    for n in tqdm(range(num_round), desc="sampling battles evenly"):
        resampled = sample_battle_even(battles, n_per_battle)
        rows.append(func_compute_elo(resampled))
    df = pd.DataFrame(rows)
    return df[df.median().sort_values(ascending=False).index]

# %%
# num_samples = int(np.min(pd.pivot_table(battles, index="model_a", columns="model_b", aggfunc="size", fill_value=1e10).values))
num_samples = 50
print("number of samples per battle pair:", num_samples)
bootstrap_even_lu = get_bootstrap_even_sample(battles, num_samples, compute_elo)
# Out:
# number of samples per battle pair: 50
# sampling battles evenly: 100%|██████████| 1000/1000 [00:50<00:00, 19.66it/s]

# %%
fig = visualize_bootstrap_scores(bootstrap_even_lu, f"Bootstrap of Elo Estimates - Even sample")
fig.write_html("bootstrap_elo_estimates_uniform_sampling.html", full_html=False, include_plotlyjs="cdn")
fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="0d6d8d70-f1cf-460f-8018-a5e976c0f796" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0d6d8d70-f1cf-460f-8018-a5e976c0f796")) {                    Plotly.newPlot(                        "0d6d8d70-f1cf-460f-8018-a5e976c0f796",                        [{"error_y":{"array":[80.00209351447961,82.58539644972757,90.72416774899511,84.06066194903451,84.20028766877738,84.27982522243065,90.441631916299,85.94237569701534,69.38439089934786],"arrayminus":[88.76632476361056,78.39614574670236,79.61170796207091,85.60780518521244,76.96993305481658,86.54624004723712,78.52046987946983,86.17537943536286,77.66753353483807]},"hovertemplate":"model=%{x}<br>rating=%{y}<br>rating_rounded=%{text}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers+text","name":"","orientation":"v","showlegend":false,"text":[1177.79,1097.71,1008.92,1007.24,1005.87,989.38,941.1,902.31,871.34],"x":["vicuna-13b","koala-13b","oasst-pythia-12b","stablelm-tuned-alpha-7b","alpaca-13b","chatglm-6b","dolly-v2-12b","llama-13b","fastchat-t5-3b"],"xaxis":"x","y":[1177.787537070863,1097.7131666769778,1008.9153908327294,1007.240391004608,1005.8731059666139,989.3803746976614,941.1037732991524,902.3051173990095,871.3423575313359],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921" ...

# %%
px.violin(bootstrap_even_lu.melt(), x="variable", y="value")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="16ad7df4-d499-4c95-aec8-3f7d647e521e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("16ad7df4-d499-4c95-aec8-3f7d647e521e")) {                    Plotly.newPlot(                        "16ad7df4-d499-4c95-aec8-3f7d647e521e",                        [{"alignmentgroup":"True","box":{"visible":false},"hovertemplate":"variable=%{x}<br>value=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","offsetgroup":"","orientation":"v","scalegroup":"True","showlegend":false,"x":["vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-13b","vicuna-1 ...

# %% [markdown]
# # Links

# %% [markdown]
# Some good resources to learn more about Elo rating systems:
# - Wikipedia https://en.wikipedia.org/wiki/Elo_rating_system
# - An introduction video https://www.youtube.com/watch?v=AsYfbmp0To0
# - A FiveThirtyEight article https://fivethirtyeight.com/methodology/how-our-nfl-predictions-work/
